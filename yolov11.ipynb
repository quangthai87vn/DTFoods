# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# Train the model on the COCO8 example dataset for 100 epochs
#results = model.train(data="coco8.yaml", epochs=100, imgsz=640)
results = model.train(
    data="dataset/yolo.yaml",
    epochs=1,
    imgsz=640,
    project="runs",              # thư mục project muốn lưu (tương đối so với DTFoods)
    name="dtfoods_yolov8n",      # tên experiment
)

# Run inference with the YOLO11n model on the 'bus.jpg' image
results = model("test/1.jpg")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 6.4MB/s 0.8s.8s<0.0s1.1s
# Ultralytics 8.3.230 🚀 Python-3.10.0 torch-2.9.1 CPU (Apple M2)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset/yolo.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=1, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=dtfoods_yolov8n2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/admin/Documents/DTFoods/runs/dtfoods_yolov8n2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=12
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    433012  ultralytics.nn.modules.head.Detect           [12, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,592,180 parameters, 2,592,164 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 978.6±780.4 MB/s, size: 49.4 KB)
# train: Scanning /Users/admin/Documents/DTFoods/dataset/labels/train.cache... 704 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 704/704 2.7Mit/s 0.0s0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 949, len(boxes) = 1028. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1057.2±534.8 MB/s, size: 40.5 KB)
# val: Scanning /Users/admin/Documents/DTFoods/dataset/labels/valid.cache... 65 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 65/65 342.1Kit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 105, len(boxes) = 114. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /Users/admin/Documents/DTFoods/runs/dtfoods_yolov8n2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000625, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/admin/Documents/DTFoods/runs/dtfoods_yolov8n2
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1         0G     0.7804      3.671      1.349         48        640: 100% ━━━━━━━━━━━━ 44/44 5.8s/it 4:166.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.4s/it 10.2s9.8ss
#                    all         65        114     0.0111      0.889      0.161      0.117
#
# 1 epochs completed in 0.074 hours.
# Optimizer stripped from /Users/admin/Documents/DTFoods/runs/dtfoods_yolov8n2/weights/last.pt, 5.5MB
# Optimizer stripped from /Users/admin/Documents/DTFoods/runs/dtfoods_yolov8n2/weights/best.pt, 5.5MB
#
# Validating /Users/admin/Documents/DTFoods/runs/dtfoods_yolov8n2/weights/best.pt...
# Ultralytics 8.3.230 🚀 Python-3.10.0 torch-2.9.1 CPU (Apple M2)
# YOLO11n summary (fused): 100 layers, 2,584,492 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.2s/it 9.7s9.3s9s
#                    all         65        114      0.011      0.889      0.162      0.118
#                  Apple          6         15    0.00428          1       0.25      0.207
#               Chapathi          7          7    0.00556          1     0.0228     0.0131
#          Chicken Gravy          6          6    0.00557          1     0.0242     0.0155
#                  Fries          6          6    0.00865      0.833      0.141     0.0814
#                   Idli          6         14    0.00282          1     0.0961     0.0518
#                  Pizza          6          6     0.0118          1     0.0483     0.0335
#                   Rice          7          7     0.0429          1      0.321      0.271
#                   Soda          6          7    0.00459          1     0.0176     0.0101
#                   Vada          6         36     0.0214      0.944      0.283      0.245
#                 banana          1          1          0          0          0          0
#                 burger          9          9     0.0132          1      0.574      0.365
# Speed: 1.0ms preprocess, 136.6ms inference, 0.0ms loss, 7.6ms postprocess per image
# Results saved to /Users/admin/Documents/DTFoods/runs/dtfoods_yolov8n2
#
# image 1/1 /Users/admin/Documents/DTFoods/test/1.jpg: 384x640 (no detections), 34.0ms
# Speed: 1.0ms preprocess, 34.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
