# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)

# %%
# !pip install --target="/content/drive/MyDrive/Colab Notebooks/Yolo8" ultralytics

# %%
import os
import sys
#!pip install ultralytics
os.environ["PYTHONPATH"]="/Detection"
from ultralytics import YOLO
model = YOLO("yolov8n.yaml")

# Use the model
results = model.train(data="dataset/yolo.yaml", epochs=1, pretrained=True, iou=0.5, visualize=True, patience=0)  # train the model
results = model.val()

# %%
from ultralytics import YOLO

# Load an Open Images Dataset V7 pretrained YOLOv8n model
model = YOLO("yolov8n-oiv7.pt")

# Run prediction
results = model.predict(source="test/1.jpg")

# Start training from the pretrained checkpoint
results = model.train(data="dataset/yolo.yaml", epochs=1, imgsz=640)
# Out:
# image 1/1 /Users/admin/Documents/DTFoods/test/1.jpg: 384x640 6 Foods, 1 Salad, 1 Vegetable, 49.0ms
# Speed: 1.3ms preprocess, 49.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Ultralytics 8.3.230 🚀 Python-3.10.0 torch-2.9.1 CPU (Apple M2)
# ...
